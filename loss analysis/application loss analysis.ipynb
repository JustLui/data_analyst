# %% [markdown]
# # Исследование развлекательного приложения Procrastinate Pro+
#
#    **Описание проекта:**
#
#    Я, маркатинговый аналитик развлекательного приложения Procrastinate Pro+.Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
#    **Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:**
#    - лог сервера с данными об их посещениях,
#    - выгрузка их покупок за этот период,
#    - рекламные расходы.
#
#
#  **Предстоит изучить:**
#    - откуда приходят пользователи и какими устройствами они пользуются,
#    - сколько стоит привлечение пользователей из различных рекламных каналов;
#    - сколько денег приносит каждый клиент,
#    - когда расходы на привлечение клиента окупаются,
#    - какие факторы мешают привлечению клиентов.
#
#    **Постановка задачи:**
#
#    Разобраться в причинах и помочь компании выйти в плюс.
#
#    **Описание данных:**
#
#    Структура visits_info_short:
#    - User Id — уникальный идентификатор пользователя,
#    - Region — страна пользователя,
#    - Device — тип устройства пользователя,
#    - Channel — идентификатор источника перехода,
#    - Session Start — дата и время начала сессии,
#    - Session End — дата и время окончания сессии.
#
#    Структура orders_info_short:
#    - User Id — уникальный идентификатор пользователя,
#    - Event Dt — дата и время покупки,
#    - Revenue — сумма заказа.
#
#    Структура costs_info_short:
#    - dt — дата проведения рекламной кампании,
#    - Channel — идентификатор рекламного источника,
#    - costs — расходы на эту кампанию.
#
# **Исследование пройдет в 6 этапов:**
#
#  1. Загрузим данные и подготовим их к анализу:
#        - 1.1 Загрузим нужные библиотеки и выведем информацию по таблицам
#        - 1.2 Переименуем названия столбцов и отредактируем типы данных
#        - 1.3 Поиск и обработка дубликатов, пропусков
#        - 1.4 Промежуточный вывод
#  2. Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии:
#        - 2.1 Напишем функции для вычисления значений метрик:
#             - 2.1.1 - `get_profiles()` — для создания профилей пользователей,
#             - 2.1.2 - `get_retention()` — для подсчёта Retention Rate,
#             - 2.1.3 - `get_conversion()` — для подсчёта конверсии,
#             - 2.1.4 - `get_ltv()` — для подсчёта LTV.
#        - 2.2 Напишем функции для построения графиков:
#             - 2.2.1 - `filter_data()` — для сглаживания данных,
#             - 2.2.2 - `plot_retention()` — для построения графика Retention Rate,
#             - 2.2.3 - `plot_conversion()` — для построения графика конверсии,
#             - 2.2.4 - `plot_ltv_roi` — для визуализации LTV и ROI.
#             - 2.2.5 - `plot_bar` — для построения столбчатых диаграмм
#             - 2.2.6 - `plot_bar` — для построения круговых графиков
#  3. Исследовательский анализ данных:
#        - 3.1 Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.
#        - 3.2 Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего                      платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой        страны.
#        - 3.3 Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
#        - 3.4 Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#  4. Маркетинг:
#        - 4.1 Посчитаем общую сумму расходов на маркетинг.
#        - 4.2 Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
#        - 4.3 Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
#        - 4.4 Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#  5. Оценим окупаемость рекламы:
#        - 5.1 Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
#        - 5.2 Проверим конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Построим и изучим графики конверсии и удержания:
#             - 5.2.1 Проверим удержание пользователей и динамику её изменения
#             - 5.2.2 Проверим конверсию пользователей и динамику её изменения
#        - 5.3 Проанализируем окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#        - 5.4 Проанализируем окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#        - 5.5 Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#             - 5.5.1  Проверим гипотезу о том, что затраты на рекламный канал TipTop делают убыточной всю рекламную компанию в целом:
#         - 5.6 Ответьтим на такие вопросы:
#              - Окупается ли реклама, направленная на привлечение пользователей в целом?
#              - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#              - Чем могут быть вызваны проблемы окупаемости?
#  6. Вывод и рекомендации

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 1.  Загрузим данные и подготовим их к анализу</b></font>

# %% [markdown]
# **План:**
# - 1.1 Загрузим нужные библиотеки и выведем информацию по таблицам
# - 1.2 Переименуем названия столбцов и отредактируем типы данных
# - 1.3 Поиск и обработка дубликатов, пропусков
# - 1.4 Промежуточный вывод

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 1.1 Загрузим нужные библиотеки и выведем информацию по таблицам</b></font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
import numpy as np

# %%
visits, orders, costs = (pd.read_csv('visits_info_short.csv'),
                         pd.read_csv('orders_info_short.csv'),
                         pd.read_csv('costs_info_short.csv')
)

# %% [markdown]
# - *Выводим таблицы на экран:*

# %%
display(visits.head(),
        orders.head(),
        costs.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# - *Смотрим информацию по ним:*

# %%
visits.info(),
orders.info(),
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# **Можно сделать промежуточный вывод о том, что пропусков в данных нет. Есть колонки которые нужно переименовать, для удобного дальнейшего использования, так же некоторые столбцы нужно поменять типы данных**

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 1.2 Переименуем названия столбцов и отредактируем типы данных</b></font>

# %% [markdown]
# - *Редактируем названия колонок к более удобному формату:*

# %%
visits.columns = visits.columns.str.replace(' ', '_').str.lower()
orders.columns = orders.columns.str.replace(' ', '_').str.lower()
costs.columns = costs.columns.str.lower()

# %% [markdown]
# - *Меняем формат дат, в удобный для дальнейшей работы с ними:*

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 1.3 Поиск и обработка дубликатов, пропусков</b></font>

# %% [markdown]
# - *Проверяем наличие дубликатов:*

# %%
print('Дубликаты в Visits: \n', sum(visits.duplicated()),
      '\nДубликаты в Orders: \n', sum(visits.duplicated()),
      '\nДубликаты в Costs: \n', sum(visits.duplicated()))
# Out:
# Дубликаты в Visits:
#  0
# Дубликаты в Orders:
#  0
# Дубликаты в Costs:
#  0

# %% [markdown]
# - *Проверяем наличие пропусков:*

# %%
print('Пропуски в Visits: \n',visits.isna().sum(),
      '\n\nПропуски в Orders: \n',costs.isna().sum(),
      '\n\nПропуски в Costs: \n',orders.isna().sum())
# Out:
# Пропуски в Visits:
#  user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
#
# Пропуски в Orders:
#  dt         0
# channel    0
# costs      0
# dtype: int64
#
# Пропуски в Costs:
#  user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 1.4 Промежуточный вывод</b></font>

# %% [markdown]
# **Получили 3 файла с таблицами:**
# - visits - хранит лог сервера с информацией о посещениях сайта
# - orders - хранит информацию о заказах
# - costs  - хранит  информацию о расходах на рекламу.
#
# *Вывели информацию по этим таблицам.*
#  *Отредкатировали названия колонок к более удобному формату.*
#  *Проверили на наличие пропусков и дубликатов.*

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2 Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии</b></font>

# %% [markdown]
# **План:**
#
# 2.1 Напишем функции для вычисления значений метрик:
#
# - 2.1.1 - `get_profiles()` — для создания профилей пользователей,
# - 2.1.2 - `get_retention()` — для подсчёта Retention Rate,
# - 2.1.3 - `get_conversion()` — для подсчёта конверсии,
# - 2.1.4 - `get_ltv()` — для подсчёта LTV.
#
# 2.2 Напишем функции для построения графиков:
#
# - 2.2.1 - `filter_data()` — для сглаживания данных,
# - 2.2.2 - `plot_retention()` — для построения графика Retention Rate,
# - 2.2.3 - `plot_conversion()` — для построения графика конверсии,
# - 2.2.4 - `plot_ltv_roi` — для визуализации LTV и ROI.
# - 2.2.5 - `plot_bar` — для построения столбчатых диаграмм
# - 2.2.6 - `plot_bar` — для построения круговых графиков

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.1 Напишем функции для вычисления значений метрик:</b></font>

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.1.1 Функция для создания пользовательских профилей:</b></font>

# %%
def get_profiles(sessions, orders, ad_costs, event_names=[]):

    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.1.2 Функция для расчёта удержания:</b></font>

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    dimensions = ['payer'] + dimensions

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.1.3 Функция для расчёта конверсии:</b></font>

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    if 'cohort' in dimensions: 
        dimensions = []

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.1.4 Функция для расчёта LTV и ROI:</b></font>

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes

        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        roi = result.div(cac['cac'], axis=0)

        roi = roi[~roi['cohort_size'].isin([np.inf])]

        roi['cohort_size'] = cohort_sizes

        roi['cac'] = cac['cac']

        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    if 'cohort' in dimensions:
        dimensions = []

    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,
        result_grouped,
        result_in_time,
        roi_grouped,
        roi_in_time,
    )

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2 Напишем функции для построения графиков:</b></font>

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.1 Функция для сглаживания фрейма:</b></font>

# %%
def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.2 Функция для визуализации удержания:</b></font>

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    plt.figure(figsize=(15, 10))

    retention = retention.drop(columns=['cohort_size', 0])
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    ax3 = plt.subplot(2, 2, 3)
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.3 Функция для визуализации конверсии:</b></font>

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    plt.figure(figsize=(15, 5))

    conversion = conversion.drop(columns=['cohort_size'])
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.4 Функция для визуализации LTV и ROI:</b></font>

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(20, 12))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    cac_history = roi_history[['cac']]

    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=2, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.5 Функция для построения столбчатых диаграмм:</b></font>

# %%
def plot_bar(data, dimensions='payer_percent', ylabel=' ', title = ' ', sort_value = ' '):
    data = data.sort_values(by=sort_value, ascending=False)
    plt.figure(figsize=(14, 5))
    ax = sns.barplot(data=data, 
                     x='channel', 
                     y=dimensions)

    ax.set(title=title,
           xlabel='Канал привлечения',
           ylabel= ylabel)
    plt.xticks(rotation=40)
    ax.grid(True)

    plt.show()

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 2.2.6  Функция для построения круговых графиков:</b></font>

# %%
def plot_pie(df, dimensions='region', title=' '):
    
    fig, axis = plt.subplots(1, 3, figsize=(14, 5))
    data_keys = ['count_users', 'payer', 'payer_percent']

    for i, key in enumerate(data_keys):
        axis[i].pie(df[key], 
                    labels=df[dimensions], 
                    autopct='%1.1f%%', 
                    startangle=90)
        axis[i].set_title(title[i])

    plt.show()

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 3 Исследовательский анализ данных</b></font>

# %% [markdown]
# **План:**
# - 3.1 Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.
# - 3.2 Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - 3.3 Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - 3.4 Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 3.1 Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.</b></font>

# %% [markdown]
# - *Получаем профили пользователей:*

# %%
profiles = get_profiles(visits, orders, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# - *Определяем минимальную и максимальную дату привлечения:*

# %%
print('Минимальная дата привлечения:', profiles['dt'].min(),
      '\nМаксимальная дата привлечения:', profiles['dt'].max()
      )
# Out:
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 3.2 Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.</b></font>

# %% [markdown]
# - *Сделаем сводную таблицу по платящим пользователям и общим кол-вом пользователей:*

# %%
count_users_region = (profiles.pivot_table(index=['region'], 
                          values=['user_id', 'payer'], 
                          aggfunc = {'user_id' : 'count', 'payer' : 'sum'})
                          .sort_values(by='user_id', ascending=False)
                          .reset_index())
count_users_region = count_users_region.rename(columns={'user_id': 'count_users'})
count_users_region['payer_percent'] = round(count_users_region['payer'] / 
                                            count_users_region['count_users'] * 100, 1)
count_users_region
# Out:
#           region  payer  count_users  payer_percent
# 0  United States   6902       100002            6.9
# 1             UK    700        17575            4.0
# 2         France    663        17450            3.8
# 3        Germany    616        14981            4.1

# %% [markdown]
# - *Построим 2 диаграммы для визуального отображения общего кол-ва пользователей и платящих пользователей:*

# %%
plot_pie(count_users_region, 
         dimensions='region', 
         title = ['Распределение \n пользователей по регионам',
              'Распределение платящих \n пользователей по регионам',
              'Доля платящих \n пользователей по регионам'])

# %% [markdown]
# **Выводы:**
# - *Подавляющее большинство пользователей из `United States` 66,7 %, далее идут `UK` и `France`, 11,7 и 11,6% , на последнем месте `Germany` 10%*
# - *Среди платящих пользователей большее кол-во из `United States` 77,7%, далее идет `UK` 7,9%, на 3 месте `France` 7,5% и на последнем месте `Germany` 6,9%*
#
#
# - *1 место по доле платящих пользователей занимает `United States`.*
# - *Но вот на 2 месте `Germany`, которая по двум предыдущим покозателям проигрывает другим странам.*

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 3.3  Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</b></font>

# %% [markdown]
# - *Сделаем сводную таблицу по устройстам с которых заходили пользователи и с каких устройств платили:*

# %%
count_users_device = (profiles.pivot_table(index='device', 
                          values=['user_id', 'payer'], 
                          aggfunc = {'user_id' : 'count', 'payer' : 'sum'})
                          .sort_values(by='user_id', ascending=False)
                          .reset_index())
count_users_device = count_users_device.rename(columns={'user_id': 'count_users'})
count_users_device['payer_percent'] = round(count_users_device['payer'] / 
                                            count_users_device['count_users'] * 100, 1)
count_users_device
# Out:
#     device  payer  count_users  payer_percent
# 0   iPhone   3382        54479            6.2
# 1  Android   2050        35032            5.9
# 2       PC   1537        30455            5.0
# 3      Mac   1912        30042            6.4

# %% [markdown]
# - *Построим диаграммы для распределения пользователей в зависимости от устройства и с каких устройств платили пользователи:*

# %%
plot_pie(count_users_device, 
         dimensions='device', 
         title = ['Распределение \n пользователей по уст-вам',
              'Распределение платящих \n пользователей по уст-вам',
              'Доля платящих \n пользователей по уст-вам'])

# %% [markdown]
# **Выводы:**
# - *Среди общего распределения по устройствам лидирует `iPhone` 36,3%, на 2 месте `Android`, на 3 и 4 `PC` и `Mac` 20,3 и 20,0%*
# - *Среди распределения платящих пользователей по устройству лидирует `iPhone` 38,1%, на 2 месте `Android`, на 3 месте `Mac` 21,5% и на 4 месте `PC` 17,3%*
#
#
# - *На 1 месте как по общему числу пользователей, так и по оплатам лидирует `iPhone`, на 2 месте по обоим показателям идет `Android`, а вот далее несмотря на то, что общее кол-во пользователей между `PC` и `Mac` почти одинаковое, но по кол-ву продаж `PC` сильно отстает от `Mac`.*
# - *Картина такова, что больше всего и общих пользователей и платящих пользуются мобильным устройством, сумммарно 60% владельцы мобильных телефонов и 40% это владельный ноутбуков или стационарных компьютеров.*
#
#
# - *Но если смотреть долю платящих пользователей от общего кол-ва пользователей по устройству, то мы видим что лучше всего пользователь совершает покупку на устройстве `Mac`.*
# - *Хуже всего конвертируются в платных пользователей, пользователи `PC`*

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 3.4  Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.</b></font>

# %% [markdown]
# - *Сделаем сводную таблицу по каналам привлечения пользователей:*

# %%
count_users_channel = (profiles.pivot_table(index='channel', 
                          values=['user_id', 'payer'], 
                          aggfunc = {'user_id' : 'count', 'payer' : 'sum'})
                          .reset_index())
count_users_channel = count_users_channel.rename(columns={'user_id': 'count_users'})
count_users_channel['payer_percent'] = round(count_users_channel['payer'] / 
                                             count_users_channel['count_users'] * 100, 1)
count_users_channel
# Out:
#                channel  payer  count_users  payer_percent
# 0           AdNonSense    440         3880           11.3
# 1             FaceBoom   3557        29144           12.2
# 2              LeapBob    262         8553            3.1
# 3         MediaTornado    156         4364            3.6
# 4   OppleCreativeMedia    233         8605            2.7
# 5       RocketSuperAds    352         4448            7.9
# 6               TipTop   1878        19561            9.6
# 7       WahooNetBanner    453         8553            5.3
# 8              YRabbit    165         4312            3.8
# 9       lambdaMediaAds    225         2149           10.5
# 10             organic   1160        56439            2.1

# %% [markdown]
# - *Построим столбчатую диаграмму для кол-ва пользователей для каждого канала привлечения:*

# %%
plot_bar(count_users_channel, dimensions='count_users', 
                   ylabel='Кол-во пользователей', 
                   title='Кол-во пользователей в зависимости от канала привлечения',
                   sort_value='count_users')

# %% [markdown]
# **Больше в всего платных пользователей у канала привлечения `FaceBoom`, это как раз тот канал на который тратились деньги на рекламу, на 2 месте канал `TipTop`, на 3 месте `Organic`**

# %% [markdown]
# - *Построим столбчатую диаграмму с долей конверсии пользователей в платящих пользователей:*

# %%
plot_bar(count_users_channel, dimensions='payer_percent', 
                   ylabel='Доля в %', 
                   title='Процент платящих пользователей в зависимости от канала',
                   sort_value='payer_percent')

# %% [markdown]
# **На 1 месте канал `FaceBoom`, на нем больше всего пользователей превращаются в платных пользователей. На 2 месте канал `AdNonSense`, на 3 месте канал `LambaMediAds`, на 4 месте канал `TipTop`**
#
# **От органики так мало платящих, так как зачастую закупочные каналы оптимизируются с целью приведения максимально платящей аудитории, а органические пользователи случаются разные**

# %% [markdown]
# **Выводы:**
# - Больше всего пользователей привлечены через каналы `Organic`, `FaceBoom`, `TipTop` - 1,2 и 3 место соответственно.
# - Кол-во платящих пользователйе больше всего у `FaceBoom`, на 2 и 3 месте `TipTop` и `Organic`
#
#
# - Если смотреть на долю платящих пользователей, то `Organic` оказался на последнем месте, из-за того что туда попадают все подряд пользователи, там нет целевой аудитории, поэтому там больше всего пользователей, но и меньше всего конверсия в платящих.
# - У канала `FaceBoom` самая большая доля платящих пользователей 12,2%.
# - На 2 и 3 месте каналы `AdNonSense` и `LambdaMediaAds` - составляют 11,3 и 10,5 %.

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 4 Маркетинг</b></font>

# %% [markdown]
# - 4.1 Посчитаем общую сумму расходов на маркетинг.
# - 4.2 Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - 4.3 Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - 4.4 Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 4.1 Посчитаем общую сумму расходов на маркетинг.</b></font>

# %% [markdown]
# - *Посчитаем общую сумму расходов на маркетинг:*

# %%
total = round(sum(costs['costs']))
print('Общая сумма расходов составляет:', total)
# Out:
# Общая сумма расходов составляет: 105497

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 4.2 Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.</b></font>

# %% [markdown]
# - *Сделаем сводную таблицу по сумме общих расходов в зависимости от рекламного источника на маркетинг:*

# %%
total_expenses = (costs.pivot_table(index='channel', 
                          values = 'costs', 
                          aggfunc = 'sum')
              .sort_values(by='costs', ascending=False)
              .reset_index())
total_expenses.costs = round(total_expenses.costs)
total_expenses
# Out:
#               channel    costs
# 0              TipTop  54751.0
# 1            FaceBoom  32446.0
# 2      WahooNetBanner   5151.0
# 3          AdNonSense   3911.0
# 4  OppleCreativeMedia   2151.0
# 5      RocketSuperAds   1833.0
# 6             LeapBob   1798.0
# 7      lambdaMediaAds   1558.0
# 8        MediaTornado    954.0
# 9             YRabbit    944.0

# %%
plot_bar(total_expenses, dimensions='costs', 
                   ylabel='Траты на рекламу', 
                   title='Сумма трат на рекламу по источникам',
                   sort_value='costs')

# %% [markdown]
# **Больше всего денег было потрачено на рекламу канала `TipTop` и `FaceBoom`. На остальные каналы потрачено гораздо меньше денег. Выясним, окупились ли такие затраты.**

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 4.3 Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.</b></font>

# %% [markdown]
# - *Создаем копию датафрейма costs, что бы поменять тип данных даты на нужный для корректной работы:*

# %%
costs_copy = costs.copy()
costs_copy['dt'] = pd.to_datetime(costs_copy['dt'])

# %% [markdown]
# - *Добавляем отдельный столбцы с номером недели и месяца:*

# %%
costs_copy['week'] = costs_copy['dt'].dt.isocalendar().week
costs_copy['month'] = costs_copy['dt'].dt.month

# %% [markdown]
# - *Строим график с визуализацией динамики изменения расходов по неделям:*

# %%
grouped_data = costs_copy.groupby(['channel', 'week'])['costs'].sum().reset_index()


plt.figure(figsize=(12, 8))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', '#FFA500', '#008080', '#800080']

for i, (channel, data_group) in enumerate(grouped_data.groupby('channel')):
    plt.plot(data_group['week'], data_group['costs'], 
             label=channel, color=colors[i], 
             linestyle='-', marker='o')

plt.title('Динамика изменения расходов по источникам')
plt.xlabel('Неделя')
plt.ylabel('Расходы')
plt.xticks(range(min(costs_copy['week']), max(costs_copy['week'])+1, 2))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - **Явно выделяются два канала `FaceBoom` и `TipTop`, расходы которых сильно больше нежели у других источников.**
# - **Расходы на `FaceBoom` выглядят более равномерно, в среднем в районе 1500**
# - **Расходы `TipTop` постоянно растут и в пике доходили до 4000**
# - **Видны пики расходов на 22, 26, 39 неделе. Причем у всех каналов привлечения**

# %%
data_month = costs_copy.groupby(['channel', 'month'])['costs'].sum().reset_index()

channels = costs['channel'].unique()
plt.figure(figsize=(12, 8))

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', '#FFA500', '#008080', '#800080']

for i, channel in enumerate(channels):
    channel_data = data_month[data_month['channel'] == channel]
    plt.plot(channel_data['month'], channel_data['costs'], 
             label=channel, color=colors[i], 
             linestyle='-', marker='o')

plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.title('Динамика изменения расходов по источникам, по месяцам')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - **Видим что канал `TipTop` постоянно повышает расходы от месяца к месяцу и  в пике достиг 11000 в 9 месяце и потом пошел спад**
# - **`FaceBoom` имеет более равномерные расходы от месяца к месяцу**
# - **Все остальные каналы так же имеют равномерные расходы по месяцам**

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 4.4 Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.</b></font>

# %% [markdown]
# - *Создадим сводную таблицу что бы определить расходы на привлечение 1 пользователя:*

# %%
one_user_costs = (profiles.pivot_table(index='channel', 
                                      values='acquisition_cost', 
                                      aggfunc='mean')
                            .reset_index())
one_user_costs.acquisition_cost = round(one_user_costs.acquisition_cost, 2)
one_user_costs
# Out:
#                channel  acquisition_cost
# 0           AdNonSense              1.01
# 1             FaceBoom              1.11
# 2              LeapBob              0.21
# 3         MediaTornado              0.22
# 4   OppleCreativeMedia              0.25
# 5       RocketSuperAds              0.41
# 6               TipTop              2.80
# 7       WahooNetBanner              0.60
# 8              YRabbit              0.22
# 9       lambdaMediaAds              0.72
# 10             organic              0.00

# %% [markdown]
# - *Отобращзим эти данные на графике:*

# %%
plot_bar(one_user_costs, dimensions='acquisition_cost', 
                   ylabel='Расход', 
                   title='Средний расход на одного пользователя',
                   sort_value='acquisition_cost')

# %% [markdown]
# **В среднем на 1 пользователя больше всего потратили из канала `TipTop` 2,79. На 2 и 3 месте находятся `FaceBoom` и `AdNonSense`. У `Organic` 0, это и логично, потому что эти пользователи приходят сами, если бы там были траты это было бы странно.**

# %% [markdown]
# **Выводы:**
# - *Всего на маркетинг потратили 105497, из них половина ушла на `TipTop` - 54751, на 2 месте по тратам `FaceBoom` - 32445*
# - *Больше всего на рекламу потратили из канала `TipTop` и в промежутках времени траты на этот канал только росли, они же имеют самую большую цифру затрат в среднем не 1 пользователя 2,79, этот показатель больше в 1.5 раза чем находящийся на 2 месте канал `FaceBoom`*
# - *Канал `FaceBoom` показывает 2 показатель по затратам на 1 пользователя в среднем 1,11. Если смотреть динамику, то на рекламу из этого канала в среднем тратили стабильно одинаковую сумму*

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 5. Оценим окупаемость рекламы</b></font>

# %% [markdown]
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - 5.1 Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - 5.2 Проверим конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания:
#     - 5.2.1 Проверим удержание пользователей и динамику её изменения
#     - 5.2.2 Проверим конверсию пользователей и динамику её изменения
# - 5.3 Проанализируем окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - 5.4 Проанализируем окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - 5.5 Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#     - 5.5.1  Проверим гипотезу о том, что затраты на рекламный канал TipTop делают убыточной всю рекламную компанию в целом:
# - 5.6 Ответьтим на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 5.1 Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.</b></font>

# %% [markdown]
# - *Установим горизонт и момент анализа:*

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %% [markdown]
# - *Удаляем пользователей которые пришли через канал `organic`, т.к. нам нужно посчитать показатели для привлеченных через каналы на которые тратились деньги:*

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# - *Считаем LTV и ROI:*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# %% [markdown]
# - *Строим графики для LTV, CAC и ROI:*

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **По графикам можно сделать такие выводы:**
# - **Стабильность `LTV` и рост `CAC`, может говорить о росте конкуренции на канале или увеличением бюджета по каналу**
# - **Реклама не окупается `ROI` в конце 2 недель, чуть ниже уровня окупаемости, порядка 80%**
# - **`САС`, т.е. стоимость привлечения 1 пользователя постоянно растет, возможно поэтому не получили окупаемость**
# - **`LTV` постоянно растет, значит дело не в ухудшении качества пользователей**
# - **Динамика `LTV` так же показывает, что в среднем там все стабильно**
# - **Видим что `ROI` начинает падать ниже уровня окупаемости, у пользователей зарегестрированых после 2019-06**

# %% [markdown]
# ## <font color='DarkBlue'><b>Шаг 5.2 Проверим конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.</b></font>

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 5.2.1 Проверим удержание пользователей и динамику её изменения.</b></font>

# %% [markdown]
# - *Считаем удержание:*

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

# %% [markdown]
# - *Строим графики удержания:*

# %%
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - **Удержание платящих пользователей находится на достаточно низком уровне и сильно снижается с течением времени**
# - **Удержание не платящих пользователей к 6 дню пользования составляет менее 5% и дальше стремительно падает в 0**
# - **В динамике удержания платящих пользователей виден средний показатель в 10%. Есть пик в начале Июня, возможно там реклама имела хороший потенциал, но дальше стремительно падает вниз**

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 5.2.2 Проверим конверсию пользователей и динамику её изменения.</b></font>

# %% [markdown]
# - *Считаем конверсию:*

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

# %% [markdown]
# - *Строим графики конверсии:*

# %%
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# - **Конверсия пользователей находится на высоком уровне и постоянно растет**

# %% [markdown]
# ## <font color='DarkBlue'><b>Шаг 5.3 Проанализируем окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</b></font>

# %% [markdown]
# - *Считаем LTV , ROI с разбивкой по устройствам:*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

# %% [markdown]
# - *Строим графики:*

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - **`LTV` показатель постоянно растет и это хорошо**
# - **Динамика `LTV` показывает что показатели у `PC` чуть больше падают время от времени**
# - **По стоимости привлечения `CАС` видим что меньеш всего денег на 1 пользователя тратилось на пользователей `PC`, больше всего тратилось на пользователей `Mac` и `iPhone`**
# - **На графике окупаемости `ROI` видим что окупились только пользователи `PC`, пользователи остальных девайсов не окупились**
# - **Если смотреть на динамику, то начиная с мая окупаемость `ROI` постоянно падает**

# %% [markdown]
# - *Конверсия пользователей по дивайсам:*

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# - *Удержание платящих пользователей:*

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - **С удержанием по всем устройствам достаточно сильное падение к 14 дню, с 40 до 10%**
# - **Хуже всего удерживается `iPhone`, лучше всего `PC`**

# %% [markdown]
# ## <font color='DarkBlue'><b>Шаг 5.4 Проанализируем окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</b></font>

# %% [markdown]
# - *Считаем LTV , ROI с разбивкой по странам:*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

# %% [markdown]
# - *Строим графики:*

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - **Все страны кроме `United States` окупаются, причем окупаются на 5 день**
# - **По динамике окупаемости `ROI` видно что начиная с середины Июня новые пользователи все меньше окупаются**

# %% [markdown]
# - *Посчитаем конверсию:*

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# - **Конверсия у региона `US` гораздо выше чем у других регионов и растет лучше с течением времени**

# %% [markdown]
# - *Посчитаем удержание:*

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - **Но вот с удержанием у `US` проблема, этот регион на порядок хуже удерживает своих платящих клиентов**
# - **Любопытно, что динамика конверсии `US` становится с течением времени не такой волатильной.**

# %% [markdown]
# ## <font color='DarkBlue'><b>Шаг 5.5 Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</b></font>

# %% [markdown]
# - *Считаем LTV , ROI с разбивкой по рекламным каналам:*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

# %% [markdown]
# - *Строим графики:*

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - **Динамика стоимости привлечения `CAC` у рекламного канала `TipTop` постоянно растет и окупаемости в целом не достигает**
# - **Так же не окупаются каналы `FaceBoom` и `AdNonSense`**
# - **Лучше всего окупается канал `YRabbit`**
# - **Разобрались с LTV И ROI, получили явную проблему в `US` и `TIp Top с Faceboom`, при учете, что `US` - страна с наибольшим количеством пользователей, а `Tip TOp` и `FaceBoom` - крупнешие каналы для нас это важные находки, дальше с которыми стоит работать**

# %% [markdown]
# - *Посмотрим удержание:*

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# - **Лучшая конверсию у канала `FaceBoom`, на 2 месте `AdNonSense`, на 3 месте `LambdaMediaAds`, на 4 месте `TipTop`**

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - **Но вот с удержанием у `FaceBoom` все очень плохо, этот канал хуже всех удерживает платящих пользователей, вместе с ним `AdNonSense` который на 2 месте по конверсии пользователей**
# - **И так получается 1 и 2 месте по конверсии находятся на последних 2 места по удержанию**

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 5.5.1  Проверим гипотезу о том, что затраты на рекламный канал TipTop делают убыточной всю рекламную компанию в целом:</b></font>

# %% [markdown]
# - *Удалим всех пользователей с рекламный каналом `TipTop` :*

# %%
profiles_without_tiptop = profiles.query('channel != "TipTop"')

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_without_tiptop, orders, observation_date, horizon_days
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - **Из этих графиков видно, что окупаемость теперь составляет 110%, что подтверждает гипотезу о том, что затраты на рекламный канал `TipTop` в целом делают всю рекламную компанию не окупаемой**

# %% [markdown]
# - *Строим графики по регионам без рекламного канала `TipTop`:*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_without_tiptop, orders, observation_date, horizon_days, dimensions=['region']
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - **Теперь окупаемость `ROI` составляет 97%, c рекламным каналом `TipTop` этот показатель был около 62%**

# %% [markdown]
# - *Сделаем сводную таблицу по региону United States:*

# %%
profiles_region_united_states = profiles.query('channel != "organic" \
                                         and region =="United States"')
profiles_region_united_states = (profiles_region_united_states.pivot_table(index=['region', 'channel'], 
                                                                     values='user_id', 
                                                                     aggfunc='count')
                                                       .reset_index()
                                                       .sort_values(by='user_id', ascending = False))
profiles_region_united_states
# Out:
#           region         channel  user_id
# 0  United States        FaceBoom    29144
# 3  United States          TipTop    19561
# 2  United States  RocketSuperAds     4448
# 1  United States    MediaTornado     4364
# 4  United States         YRabbit     4312

# %% [markdown]
# - *Посмотрим есть ли в других регионах канал `TipTop` и `FaceBoom`:*

# %%
tip_top = profiles.query('(channel == "TipTop" or channel == "FaceBoom") and region != "United States"')
tip_top
# Out:
# Empty DataFrame
# Columns: [user_id, first_ts, channel, device, region, dt, month, payer, acquisition_cost]
# Index: []

# %% [markdown]
# - *Построим круговую диаграмму:*

# %%
plt.figure(figsize=(8, 6))
plt.pie(profiles_region_united_states.user_id, labels=profiles_region_united_states.channel, autopct='%1.1f%%', startangle=90)
plt.title('Круговая диаграмма пользователей по каналам, \n региона United States')
plt.show()

# %% [markdown]
# **Исходя из того, что рекламный канал `TipTop` и `FaceBoom` распространяется только на `United States`, можно сказать что именно поэтому окупаемость региона `United States` очень низкая. При том что канал `TipTop` имеет 31,6 %, а рекламный канал `FaceBoom` имеет 47,1%, рекламный канал `TipTop` тратит в примерно в 2 раза больше средств на привлечение 1 пользователя.**

# %% [markdown]
# ## <font color='DarkBlue'><b>Шаг 5.6 Ответьтим на такие вопросы:</b></font>

# %% [markdown]
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# - **Окупается ли реклама, направленная на привлечение пользователей в целом?**
# - *В целом реклама не окупается на привлечение пользователей, исходя из графика видно что показатель окупаемости `ROI`, для всех пользователей составляет 82%*
#
#
# - **Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?**
# - *Исходя из графиков негативное влияние на окупаемость рекламы могут иметь пользователей `Mac` и `iPhone`*
# - *Так же исходя их графиков видно что затраты на регион `United States` гораздо выше, чем не остальные регионы, что может негативно влиять на окупаемость рекламы*
# - *На рекламный канал `TipTop` потратили значительно большей денег, чем на все остальные, при том что остальные канала тратили на рекламу одинаково с течением времени. Поэтому затраты на рекламный канал `TipTop` может негативно влиять на окупаемость рекламы.Так же этот канал локализуется исключительно в регионе `United States`, поэтому и делает этот регион не окупаемым.*
# - *Так же видно из графиков, что рекламные каналы `FaceBoom` и `AdNonSense` не достигли уровня окупаемости за 14 дней*
#
#
# - **Чем могут быть вызваны проблемы окупаемости?**
# - *Проблема связана с большими тратами на рекламу окупаемости 1 человека в рекламной компании `TipTop` и в меньшей степени рекламная компания `FaceBoom`*
# - *Возможно есть технические проблемы и человек не может оплатить услугу, возможно уст-ва `Mac` и `iPhone` имеют проблемы с оплатой. Возможно адаптация под эти уст-ва сделана не корректно и от этого приложение может отображатся не корректно, что отталкивает пользователей*

# %% [markdown]
# ### <font color='DarkBlue'><b>Шаг 6 Выводы и рекомендации:</b></font>

# %% [markdown]
# - Выделим причины неэффективности привлечения пользователей.
# - Сформулируем рекомендации для отдела маркетинга.

# %% [markdown]
# - **Выделите причины неэффективности привлечения пользователей:**
#     - *Мы не можем назвать причин неэффективности привлечения пользователей, т.к. мы не знаем изнутри, как строилась эта реклама, какой метод рекламы там был и прочих вещей. У нас есть только цифры, мы можем лишь указать какие регионы лучше окупались, а каких хуже, можем посмотреть какие каналы лучше окупались, где лучше конверсия была а где хуже. Но назвать причины неэффективности мы не можем. Мы можем пойти в отдел маркетинга и узнать детали по каждому каналу и возможно тогда вместе с цифрами попробовать назвать причины неэффективности*
#
#
# - **Сформулируйте рекомендации для отдела маркетинга.**
#     - *Есть 3 рекламных канала которые не окупаются, это `TipTop`, `FaceBoom` и `AdNonSense`. Причем первые два локализированы на регион `United States` и имеют самые большие цифры средних затрат на одного пользователя, а так же составляют суммарно 80% от всех рекламных каналов в этом регионе и поэтому регион `Unites States` проблемный и не окупается.*
#     - *У канала `FaceBoom` хороший показатель конверсии в платных пользователей, но очень плохое удержание. Возможно стоит предлагать какие-то скидки, проводить акции, дарить что-то за непрерывную подписку.*
#     - *У канала `TipTop` хорошие показатели по конверсии, 4 место среди всех каналов и удержание также на 4 месте. Возможно из-за большой кункуренции, приходилось вкладывать больше средств и как итог отсутствие окупаемости. Стоит пересмотреть этот канал и возможно распределить ресурсы с этого канала в другие, более окупаемые*
#     - *Тут мы можем увеличить стоимость подписки для региона `United States`, т.к. средний уровень жизни в United States и странах европы не одинаковый, соответственно и затраты на рекламу тоже выше*
#     - *Так же стоит обратить внимание на рекламный канал `YRabitt`, потому что у этого канала впринципе самый высокий уровень окупаемости среди всех остальных, а т.к. он локализуется в регионе `United States`, то можно больше денег вложить в этот канал что бы повысить окупаемость в этом регионе.*
#     - *Есть еще два канала в `United States` которые хорошо окупаются, это `MediaTornado` и `RocketSuperAds`. В них тоже можно вложить больше денег.*
#     - *Лучшая окупаемость у `UK` региона, стоит посмотреть как делается реклама для этого региона и поробовать внедрить это для реклам у региона `Unites States`*
